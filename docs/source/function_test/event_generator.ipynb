# %% [markdown]
# # 1

# %%
from kmcpy.event_generator import generate_events2
from kmcpy.external.pymatgen_structure import Structure



generate_events2(prim_cif_name="data/nasicon.cif",supercell_shape=[2,1,1],local_env_cutoff_dict = {('Na+','Na+'):4,('Na+','Si4+'):4},event_fname="data/events.json",event_kernal_fname='data/event_kernal.csv',mobile_ion_specie_1_index_label_or_indices="Na1",species_to_be_removed=['Zr4+','O2-','O','Zr'],verbose=True,hacking_arg=None,convert_to_primitive_cell=False,export_reference_cluster="data/reference_cluster.cif")
# Out:
# Generating events ...
# Initializing model with input cif file at data/nasicon.cif ...
# {(0.0, 0.0, 0.14719): Comp: Zr1, (0.0, 0.0, 0.0): Comp: Na1, (-0.36033, 0.0, 0.25): Comp: Na1, (0.18534, 0.16651, 0.08652): Comp: O1, (0.18214, 0.02102, 0.19199): Comp: O1, (0.29544, 0.0, 0.25): Comp: Si1}
#
#
# -------------------------------------------
#
#
# primitive cell: Full Formula (Na24 Si18)
# Reduced Formula: Na4Si3
# abc   :   9.186300   9.186300  22.181000
# angles:  90.000000  90.000000 120.000000
# Sites (42)
#   #  SP           a         b         c  label      local_index    wyckoff_sequence
# ---  ----  --------  --------  --------  -------  -------------  ------------------
#   0  Na+   0         0         0.5       Na1                 12                   0
#   1  Na+   0         0         0         Na1                 13                   1
#   2  Na+   0.666667  0.333333  0.833333  Na1                 14                   2
# ...
